# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#se toma los valores nulos y se suman
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df_limpios = df.dropna()

# %%
df_limpios
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# Con este comento se eliminan filas(columnas) duplicadas
df_limpios = df_limpios.drop_duplicates()

# %%
df_limpios
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
df_limpios.isnull().sum()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df_limpios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  28 non-null     int64
#  1   Date      28 non-null     object
#  2   Pulse     28 non-null     int64
#  3   Maxpulse  28 non-null     int64
#  4   Calories  28 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.3+ KB

# %%
df_limpios.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
#Valores de estadistica para graficas, 
df_limpios.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   28.000000   28.000000   28.000000   28.000000
# mean    70.714286  104.250000  129.607143  307.417857
# std     74.705772    7.886345   13.273028   67.412594
# min     30.000000   92.000000  101.000000  195.100000
# 25%     60.000000  100.000000  122.250000  250.525000
# 50%     60.000000  103.000000  128.500000  300.000000
# 75%     60.000000  108.250000  133.250000  350.025000
# max    450.000000  130.000000  175.000000  479.000000

# %%
# Verificar el tipo de datos de Dte, que no es de tipo fecha
df_limpios['Date'].dtype
# Out:
# dtype('O')

# %%
df_limpios['Date']= pd.to_datetime(df_limpios['Date'], errors='coerce')
# Out:
# C:\Users\ramir\AppData\Local\Temp\ipykernel_10724\1269785752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpios['Date']= pd.to_datetime(df_limpios['Date'], errors='coerce')

# %%
df_limpios.loc['Date']= pd.to_datetime(df_limpios['Date'], errors='coerce')

# %%
df_limpios
# Out:
#      Duration       Date Pulse Maxpulse Calories
# 0          60 2020-12-01   110      130    409.1
# 1          60 2020-12-02   117      145    479.0
# 2          60 2020-12-03   103      135    340.0
# 3          45 2020-12-04   109      175    282.4
# 4          45 2020-12-05   117      148    406.0
# 5          60 2020-12-06   102      127    300.0
# 6          60 2020-12-07   110      136    374.0
# 7         450 2020-12-08   104      134    253.3
# 8          30 2020-12-09   109      133    195.1
# 9          60 2020-12-10    98      124    269.0
# 10         60 2020-12-11   103      147    329.3
# 11         60 2020-12-12   100      120    250.7
# 13         60 2020-12-13   106      128    345.3
# 14         60 2020-12-14   104      132    379.3
# 15         60 2020-12-15    98      123    275.0
# 16         60 2020-12-16    98      120    215.2
# 17         60 2020-12-17   100      120    300.0
# 19         60 2020-12-19   103      123    323.0
# ...

# %%
df_limpios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 0 to Date
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  28 non-null     object
#  1   Date      27 non-null     datetime64[ns]
#  2   Pulse     28 non-null     object
#  3   Maxpulse  28 non-null     object
#  4   Calories  28 non-null     object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 1.4+ KB

# %%
# ANALISIS DE DATOS
# Contar cuantas filas y columnas existen
print('filas y columnas', df_limpios.shape)
# Out:
# filas y columnas (29, 5)

# %%
#Muestra el nombre de las columnas
print('Columnas del dataset', df_limpios.columns.tolist())
# Out:
# Columnas del dataset ['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories']
